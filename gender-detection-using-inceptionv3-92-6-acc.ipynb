# %% [markdown]
# ## Gender Detection using InceptionV3
#
# ![face.detection.jpg](attachment:face.detection.jpg)
#
# Image recognition is one of the many applications of Machine Learning, it can solve problems for security purposes, object detection, face detection, healthcare, entertainment, among others. This application has an enormous potential to help our society, so it is important to find new uses for this tool, improve the current methods and get more accurate and useful insights from it. A good example of these applications, is the work done by research of The Chinese University of Hong Kong for face detection using deep learning (https://arxiv.org/abs/1509.06451).
#
# In this project, we will build a Machine Learning Algorithm using CNN to predict from a giving picture if the celebrity is male or female.
#
# ---
#
# ## Dataset
#
# For this project we will use the CelebA dataset (http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html), which is available on Kaggle.
#
# Description of the CelebA dataset from kaggle (https://www.kaggle.com/jessicali9530/celeba-dataset):
#
# ### Context
#
# A popular component of computer vision and deep learning revolves around identifying faces for various applications from logging into your phone with your face or searching through surveillance images for a particular suspect. This dataset is great for training and testing models for face detection, particularly for recognising facial attributes such as finding people with brown hair, are smiling, or wearing glasses. Images cover large pose variations, background clutter, diverse people, supported by a large quantity of images and rich annotations. This data was originally collected by researchers at MMLAB, The Chinese University of Hong Kong (specific reference in Acknowledgment section).
#
# ### Content
#
# #### Overall
#
# 202,599 number of face images of various celebrities
# 10,177 unique identities, but names of identities are not given
# 40 binary attribute annotations per image
# 5 landmark locations
#
# #### Data Files
#
# - <b>img_align_celeba.zip</b>: All the face images, cropped and aligned
# - <b>list_eval_partition.csv</b>: Recommended partitioning of images into training, validation, testing sets. Images 1-162770 are training, 162771-182637 are validation, 182638-202599 are testing
# - <b>list_bbox_celeba.csv</b>: Bounding box information for each image. "x_1" and "y_1" represent the upper left point coordinate of bounding box. "width" and "height" represent the width and height of bounding box
# - <b>list_landmarks_align_celeba.csv</b>: Image landmarks and their respective coordinates. There are 5 landmarks: left eye, right eye, nose, left mouth, right mouth
# - <b>list_attr_celeba.csv</b>: Attribute labels for each image. There are 40 attributes. "1" represents positive while "-1" represents negative
#
# ---

# %% [markdown]
# ### Import all the required libraries

# %%
import pandas as pd
import numpy as np
import cv2    
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score

from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.utils import np_utils
from keras.optimizers import SGD

from IPython.core.display import display, HTML
from PIL import Image
from io import BytesIO
import base64

plt.style.use('ggplot')

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.11.0-rc1

# %% [markdown]
# ## Step 1: Data Exploration
#
# We will be using the CelebA Dataset, which includes images of 178 x 218 px. Below is an example of how the pictures looks like.

# %%
# set variables 
main_folder = '../input/celeba-dataset/'
images_folder = main_folder + 'img_align_celeba/img_align_celeba/'

EXAMPLE_PIC = images_folder + '000044.jpg'

TRAINING_SAMPLES = 10000
VALIDATION_SAMPLES = 2000
TEST_SAMPLES = 2000
IMG_WIDTH = 178
IMG_HEIGHT = 218
BATCH_SIZE = 16
NUM_EPOCHS = 20

# %% [markdown]
# ### Load the attributes of every picture
# File: list_attr_celeba.csv

# %%
# import the data set that include the attribute for each picture
df_attr = pd.read_csv(main_folder + 'list_attr_celeba.csv')
df_attr.set_index('image_id', inplace=True)
df_attr.replace(to_replace=-1, value=0, inplace=True) #replace -1 by 0
df_attr.shape
# Out:
# (202599, 40)

# %% [markdown]
# ### List of the available attribute in the CelebA dataset
#
# 40 Attributes

# %%
# List of available attributes
for i, j in enumerate(df_attr.columns):
    print(i, j)
# Out:
# 0 5_o_Clock_Shadow
# 1 Arched_Eyebrows
# 2 Attractive
# 3 Bags_Under_Eyes
# 4 Bald
# 5 Bangs
# 6 Big_Lips
# 7 Big_Nose
# 8 Black_Hair
# 9 Blond_Hair
# 10 Blurry
# 11 Brown_Hair
# 12 Bushy_Eyebrows
# 13 Chubby
# 14 Double_Chin
# 15 Eyeglasses
# 16 Goatee
# 17 Gray_Hair
# 18 Heavy_Makeup
# 19 High_Cheekbones
# 20 Male
# 21 Mouth_Slightly_Open
# 22 Mustache
# 23 Narrow_Eyes
# 24 No_Beard
# 25 Oval_Face
# 26 Pale_Skin
# 27 Pointy_Nose
# 28 Receding_Hairline
# 29 Rosy_Cheeks
# 30 Sideburns
# 31 Smiling
# 32 Straight_Hair
# 33 Wavy_Hair
# 34 Wearing_Earrings
# 35 Wearing_Hat
# 36 Wearing_Lipstick
# 37 Wearing_Necklace
# 38 Wearing_Necktie
# 39 Young

# %% [markdown]
# ### Example of a picture in CelebA dataset
# 178 x 218 px

# %%
# plot picture and attributes
img = load_img(EXAMPLE_PIC)
plt.grid(False)
plt.imshow(img)
df_attr.loc[EXAMPLE_PIC.split('/')[-1]][['Smiling','Male','Young']] #some attributes
print("Example image")
# Out:
# Example image

# %% [markdown]
# ### Distribution of the Attribute
#
# As specified before, this Notebook is an imagine recognition project of the Gender. There are more Female gender than Male gender in the data set. This give us some insight about the need to balance the data in next steps.

# %%
# Female or Male?
plt.title('Female or Male')
sns.countplot(y='Male', data=df_attr, color="r")
plt.show()

# %% [markdown]
# ## Step 2: Split Dataset into Training, Validation and Test
#
# The recommended partitioning of images into training, validation, testing of the data set is:
# * 1-162770 are training
# * 162771-182637 are validation
# * 182638-202599 are testing
#
# The partition is in file <b>list_eval_partition.csv</b>
#
# Due time execution, by now we will be using a reduced number of images:
#
# * Training 20000 images
# * Validation 5000 images
# * Test 5000 Images

# %%
# Recomended partition
df_partition = pd.read_csv(main_folder + 'list_eval_partition.csv')
df_partition.head()
# Out:
#      image_id  partition
# 0  000001.jpg          0
# 1  000002.jpg          0
# 2  000003.jpg          0
# 3  000004.jpg          0
# 4  000005.jpg          0

# %%
# display counter by partition
# 0 -> TRAINING
# 1 -> VALIDATION
# 2 -> TEST
df_partition['partition'].value_counts().sort_index()
# Out:
# 0    162770
# 1     19867
# 2     19962
# Name: partition, dtype: int64

# %% [markdown]
# #### Join the partition and the attributes in the same data frame

# %%
# join the partition with the attributes
df_partition.set_index('image_id', inplace=True)
df_par_attr = df_partition.join(df_attr['Male'], how='inner')
df_par_attr.head()
# Out:
#             partition  Male
# image_id
# 000001.jpg          0     0
# 000002.jpg          0     0
# 000003.jpg          0     1
# 000004.jpg          0     0
# 000005.jpg          0     0

# %% [markdown]
# ### 2.1: Generate Partitions (Train, Validation, Test)
#
# Number of images need to be balanced in order to get a good performance for the model, each model will have its own folder of training, validation and test balanced data.
#
# This degree project explains how imbalanced training data impact on CNNs models:
#
# https://www.kth.se/social/files/588617ebf2765401cfcc478c/PHensmanDMasko_dkand15.pdf
#
# On this step we will create functions that will help us to create each partition.

# %%
def load_reshape_img(fname):
    img = load_img(fname)
    x = img_to_array(img)/255.
    x = x.reshape((1,) + x.shape)

    return x


def generate_df(partition, attr, num_samples):
    '''
    partition
        0 -> train
        1 -> validation
        2 -> test
    
    '''
    
    df_ = df_par_attr[(df_par_attr['partition'] == partition) 
                           & (df_par_attr[attr] == 0)].sample(int(num_samples/2))
    df_ = pd.concat([df_,
                      df_par_attr[(df_par_attr['partition'] == partition) 
                                  & (df_par_attr[attr] == 1)].sample(int(num_samples/2))])

    # for Train and Validation
    if partition != 2:
        x_ = np.array([load_reshape_img(images_folder + fname) for fname in df_.index])
        x_ = x_.reshape(x_.shape[0], 218, 178, 3)
        y_ = np_utils.to_categorical(df_[attr],2)
    # for Test
    else:
        x_ = []
        y_ = []

        for index, target in df_.iterrows():
            im = cv2.imread(images_folder + index)
            im = cv2.resize(cv2.cvtColor(im, cv2.COLOR_BGR2RGB), (IMG_WIDTH, IMG_HEIGHT)).astype(np.float32) / 255.0
            im = np.expand_dims(im, axis =0)
            x_.append(im)
            y_.append(target[attr])

    return x_, y_

# %% [markdown]
# ## Step 3: Pre-processing Images: Data Augmentation
#
# Generates Data Augmentation for iamges.
#
# Data Augmentation allows to generate images with modifications to the original ones. The model will learn from these variations (changing angle, size and position), being able to predict better never seen images that could have the same variations in position, size and position.

# %% [markdown]
# ### 3.1. Let's start with an example: Data Augmentation
#
# This is how an image will look like after data augmentation (based in the giving parameters below).

# %%
# Generate image generator for data augmentation
datagen =  ImageDataGenerator(
  #preprocessing_function=preprocess_input,
  rotation_range=30,
  width_shift_range=0.2,
  height_shift_range=0.2,
  shear_range=0.2,
  zoom_range=0.2,
  horizontal_flip=True
)

# load one image and reshape
img = load_img(EXAMPLE_PIC)
x = img_to_array(img)/255.
x = x.reshape((1,) + x.shape)

# plot 10 augmented images of the loaded iamge
plt.figure(figsize=(20,10))
plt.suptitle('Data Augmentation', fontsize=28)

i = 0
for batch in datagen.flow(x, batch_size=1):
    plt.subplot(3, 5, i+1)
    plt.grid(False)
    plt.imshow( batch.reshape(218, 178, 3))
    
    if i == 9:
        break
    i += 1
    
plt.show()

# %% [markdown]
# The result is a new set of images with modifications from the original one, that allows to the model to learn from these variations in order to take this kind of images during the learning process and predict better never seen images.

# %% [markdown]
# ### 3.2. Build Data Generators

# %%
# Train data
x_train, y_train = generate_df(0, 'Male', TRAINING_SAMPLES)

# Train - Data Preparation - Data Augmentation with generators
train_datagen =  ImageDataGenerator(
  preprocessing_function=preprocess_input,
  rotation_range=30,
  width_shift_range=0.2,
  height_shift_range=0.2,
  shear_range=0.2,
  zoom_range=0.2,
  horizontal_flip=True,
)

train_datagen.fit(x_train)

train_generator = train_datagen.flow(
    x_train, 
    y_train,
    batch_size=BATCH_SIZE,
)

# %%
# Validation Data
x_valid, y_valid = generate_df(1, 'Male', VALIDATION_SAMPLES)
# Out:
# '\n# Validation - Data Preparation - Data Augmentation with generators\nvalid_datagen = ImageDataGenerator(\n  preprocessing_function=preprocess_input,\n)\n\nvalid_datagen.fit(x_valid)\n\nvalidation_generator = valid_datagen.flow(\nx_valid, y_valid,\n)\n'

# %% [markdown]
# With the data generator created and data for validation, we are ready to start modeling.

# %% [markdown]
# ## Step 4: Build the Model - Gender Recognition

# %% [markdown]
# ### 4.1. Set the Model

# %%
# Import InceptionV3 Model
inc_model = InceptionV3(weights='../input/inceptionv3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h
0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 11, 9, 192)   258048      activation_256[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 11, 9, 192)   147456      average_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 11, 9, 192)   576         conv2d_249[0][0]
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 11, 9, 192)   576         conv2d_252[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 11, 9, 192)   576         conv2d_257[0][0]
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 11, 9, 192)   576         conv2d_258[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, 11, 9, 192)   0           batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, 11, 9, 192)   0           batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# activation_257 (Activation)     (None, 11, 9, 192)   0           batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# activation_258 (Activation)     (None, 11, 9, 192)   0           batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 11, 9, 768)   0           activation_249[0][0]
#                                                                  activation_252[0][0]
#                                                                  activation_257[0][0]
#                                                                  activation_258[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 11, 9, 192)   576         conv2d_263[0][0]
# __________________________________________________________________________________________________
# activation_259 (Activation)     (None, 11, 9, 192)   0           batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# activation_263 (Activation)     (None, 11, 9, 192)   0           batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 5, 4, 320)    552960      activation_259[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 5, 4, 192)    331776      activation_263[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 5, 4, 320)    960         conv2d_260[0][0]
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 5, 4, 192)    576         conv2d_264[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, 5, 4, 320)    0           batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# activation_264 (Activation)     (None, 5, 4, 192)    0           batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 5, 4, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 5, 4, 1280)   0           activation_260[0][0]
#                                                                  activation_264[0][0]
#                                                                  max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 5, 4, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 5, 4, 448)    1344        conv2d_269[0][0]
# __________________________________________________________________________________________________
# activation_269 (Activation)     (None, 5, 4, 448)    0           batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 5, 4, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 5, 4, 384)    1548288     activation_269[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 5, 4, 384)    1152        conv2d_266[0][0]
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 5, 4, 384)    1152        conv2d_270[0][0]
# __________________________________________________________________________________________________
# activation_266 (Activation)     (None, 5, 4, 384)    0           batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 5, 4, 384)    0           batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 5, 4, 384)    442368      activation_266[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 5, 4, 384)    442368      activation_266[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 5, 4, 384)    442368      activation_270[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 5, 4, 384)    442368      activation_270[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_26 (AveragePo (None, 5, 4, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 5, 4, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 5, 4, 384)    1152        conv2d_267[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 5, 4, 384)    1152        conv2d_268[0][0]
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 5, 4, 384)    1152        conv2d_271[0][0]
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 5, 4, 384)    1152        conv2d_272[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 5, 4, 192)    245760      average_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 5, 4, 320)    960         conv2d_265[0][0]
# __________________________________________________________________________________________________
# activation_267 (Activation)     (None, 5, 4, 384)    0           batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# activation_268 (Activation)     (None, 5, 4, 384)    0           batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, 5, 4, 384)    0           batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 5, 4, 384)    0           batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 5, 4, 192)    576         conv2d_273[0][0]
# __________________________________________________________________________________________________
# activation_265 (Activation)     (None, 5, 4, 320)    0           batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 5, 4, 768)    0           activation_267[0][0]
#                                                                  activation_268[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 5, 4, 768)    0           activation_271[0][0]
#                                                                  activation_272[0][0]
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 5, 4, 192)    0           batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 5, 4, 2048)   0           activation_265[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_5[0][0]
#                                                                  activation_273[0][0]
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 5, 4, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_278 (BatchN (None, 5, 4, 448)    1344        conv2d_278[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, 5, 4, 448)    0           batch_normalization_278[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 5, 4, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 5, 4, 384)    1548288     activation_278[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 5, 4, 384)    1152        conv2d_275[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279 (BatchN (None, 5, 4, 384)    1152        conv2d_279[0][0]
# __________________________________________________________________________________________________
# activation_275 (Activation)     (None, 5, 4, 384)    0           batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# activation_279 (Activation)     (None, 5, 4, 384)    0           batch_normalization_279[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 5, 4, 384)    442368      activation_275[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 5, 4, 384)    442368      activation_275[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 5, 4, 384)    442368      activation_279[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 5, 4, 384)    442368      activation_279[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_27 (AveragePo (None, 5, 4, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 5, 4, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276 (BatchN (None, 5, 4, 384)    1152        conv2d_276[0][0]
# __________________________________________________________________________________________________
# batch_normalization_277 (BatchN (None, 5, 4, 384)    1152        conv2d_277[0][0]
# __________________________________________________________________________________________________
# batch_normalization_280 (BatchN (None, 5, 4, 384)    1152        conv2d_280[0][0]
# __________________________________________________________________________________________________
# batch_normalization_281 (BatchN (None, 5, 4, 384)    1152        conv2d_281[0][0]
# __________________________________________________________________________________________________
# conv2d_282 (Conv2D)             (None, 5, 4, 192)    393216      average_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 5, 4, 320)    960         conv2d_274[0][0]
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, 5, 4, 384)    0           batch_normalization_276[0][0]
# __________________________________________________________________________________________________
# activation_277 (Activation)     (None, 5, 4, 384)    0           batch_normalization_277[0][0]
# __________________________________________________________________________________________________
# activation_280 (Activation)     (None, 5, 4, 384)    0           batch_normalization_280[0][0]
# __________________________________________________________________________________________________
# activation_281 (Activation)     (None, 5, 4, 384)    0           batch_normalization_281[0][0]
# __________________________________________________________________________________________________
# batch_normalization_282 (BatchN (None, 5, 4, 192)    576         conv2d_282[0][0]
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 5, 4, 320)    0           batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 5, 4, 768)    0           activation_276[0][0]
#                                                                  activation_277[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 5, 4, 768)    0           activation_280[0][0]
#                                                                  activation_281[0][0]
# __________________________________________________________________________________________________
# activation_282 (Activation)     (None, 5, 4, 192)    0           batch_normalization_282[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 5, 4, 2048)   0           activation_274[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_6[0][0]
#                                                                  activation_282[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %% [markdown]
# <h2>Inception-V3 model structure</h2>
# This is the structure of the Inception-V3 model, developed over the imagenet dataset.
#
#
# <img src="https://i.imgur.com/kdXUzu1.png" width="1000px"/>
# source: https://hackathonprojects.files.wordpress.com/2016/09/74911-image03.png
#
# The top layers (including classification) are not included. These layers will be replaced for the following layers:

# %%
#Adding custom Layers
x = inc_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation="relu")(x)
x = Dropout(0.5)(x)
x = Dense(512, activation="relu")(x)
predictions = Dense(2, activation="softmax")(x)

# %% [markdown]
# <h2>New Top layers</h2>
# Layers to be trained with the new model.
# <img src="https://i.imgur.com/rWF7bRY.png" width="800px"/>

# %%
# creating the final model 
model_ = Model(inputs=inc_model.input, outputs=predictions)

# Lock initial layers to do not be trained
for layer in model_.layers[:52]:
    layer.trainable = False

# compile the model
model_.compile(optimizer=SGD(lr=0.0001, momentum=0.9)
                    , loss='categorical_crossentropy'
                    , metrics=['accuracy'])

# %% [markdown]
# ### 4.2. Train Model

# %%
#https://keras.io/models/sequential/ fit generator
checkpointer = ModelCheckpoint(filepath='weights.best.inc.male.hdf5', 
                               verbose=1, save_best_only=True)

# %%
hist = model_.fit_generator(train_generator
                     , validation_data = (x_valid, y_valid)
                      , steps_per_epoch= TRAINING_SAMPLES/BATCH_SIZE
                      , epochs= NUM_EPOCHS
                      , callbacks=[checkpointer]
                      , verbose=1
                    )
# Out:
# Epoch 1/20
# 625/625 [==============================] - 131s 209ms/step - loss: 0.5191 - acc: 0.7417 - val_loss: 0.3358 - val_acc: 0.8660
#
# Epoch 00001: val_loss improved from inf to 0.33576, saving model to weights.best.inc.male.hdf5
# Epoch 2/20
# 625/625 [==============================] - 116s 185ms/step - loss: 0.3225 - acc: 0.8649 - val_loss: 0.2791 - val_acc: 0.8905
#
# Epoch 00002: val_loss improved from 0.33576 to 0.27905, saving model to weights.best.inc.male.hdf5
# Epoch 3/20
# 625/625 [==============================] - 115s 183ms/step - loss: 0.2677 - acc: 0.8878 - val_loss: 0.2801 - val_acc: 0.8920
#
# Epoch 00003: val_loss did not improve from 0.27905
# Epoch 4/20
# 625/625 [==============================] - 115s 184ms/step - loss: 0.2294 - acc: 0.9068 - val_loss: 0.2683 - val_acc: 0.8995
#
# Epoch 00004: val_loss improved from 0.27905 to 0.26834, saving model to weights.best.inc.male.hdf5
# Epoch 5/20
# 625/625 [==============================] - 116s 185ms/step - loss: 0.2146 - acc: 0.9099 - val_loss: 0.2375 - val_acc: 0.9140
#
# Epoch 00005: val_loss improved from 0.26834 to 0.23752, saving model to weights.best.inc.male.hdf5
# Epoch 6/20
# 625/625 [==============================] - 115s 184ms/step - loss: 0.1965 - acc: 0.9245 - val_loss: 0.2462 - val_acc: 0.9105
#
# Epoch 00006: val_loss did not improve from 0.23752
# Epoch 7/20
# 625/625 [==============================] - 115s 184ms/step - loss: 0.1810 - acc: 0.9260 - val_loss: 0.2918 - val_acc: 0.8960
#
# Epoch 00007: val_loss did not improve from 0.23752
# Epoch 8/20
# 625/625 [==============================] - 115s 183ms/step - loss: 0.1649 - acc: 0.9351 - val_loss: 0.2055 - val_acc: 0.9275
#
# Epoch 00008: val_loss improved from 0.23752 to 0.20546, saving model to weights.best.inc.male.hdf5
# Epoch 9/20
# 625/625 [==============================] - 116s 186ms/step - loss: 0.1639 - acc: 0.9369 - val_loss: 0.2220 - val_acc: 0.9215
#
# Epoch 00009: val_loss did not improve from 0.20546
# Epoch 10/20
# 625/625 [==============================] - 112s 179ms/step - loss: 0.1507 - acc: 0.9422 - val_loss: 0.2243 - val_acc: 0.9215
#
# Epoch 00010: val_loss did not improve from 0.20546
# Epoch 11/20
# 625/625 [==============================] - 112s 179ms/step - loss: 0.1470 - acc: 0.9440 - val_loss: 0.2321 - val_acc: 0.9150
#
# Epoch 00011: val_loss did not improve from 0.20546
# Epoch 12/20
# 625/625 [==============================] - 110s 176ms/step - loss: 0.1401 - acc: 0.9471 - val_loss: 0.2135 - val_acc: 0.9250
#
# Epoch 00012: val_loss did not improve from 0.20546
# Epoch 13/20
# 625/625 [==============================] - 110s 177ms/step - loss: 0.1305 - acc: 0.9499 - val_loss: 0.2107 - val_acc: 0.9280
#
# Epoch 00013: val_loss did not improve from 0.20546
# Epoch 14/20
# 625/625 [==============================] - 110s 177ms/step - loss: 0.1197 - acc: 0.9541 - val_loss: 0.2736 - val_acc: 0.8990
#
# Epoch 00014: val_loss did not improve from 0.20546
# Epoch 15/20
# 625/625 [==============================] - 111s 178ms/step - loss: 0.1193 - acc: 0.9552 - val_loss: 0.2084 - val_acc: 0.9275
#
# Epoch 00015: val_loss did not improve from 0.20546
# Epoch 16/20
# 625/625 [==============================] - 111s 178ms/step - loss: 0.1161 - acc: 0.9571 - val_loss: 0.1918 - val_acc: 0.9360
#
# Epoch 00016: val_loss improved from 0.20546 to 0.19178, saving model to weights.best.inc.male.hdf5
# Epoch 17/20
# 625/625 [==============================] - 110s 176ms/step - loss: 0.1080 - acc: 0.9582 - val_loss: 0.2614 - val_acc: 0.9070
#
# Epoch 00017: val_loss did not improve from 0.19178
# Epoch 18/20
# 625/625 [==============================] - 110s 177ms/step - loss: 0.1029 - acc: 0.9628 - val_loss: 0.2226 - val_acc: 0.9255
#
# Epoch 00018: val_loss did not improve from 0.19178
# Epoch 19/20
# 625/625 [==============================] - 112s 179ms/step - loss: 0.0960 - acc: 0.9647 - val_loss: 0.2267 - val_acc: 0.9235
#
# Epoch 00019: val_loss did not improve from 0.19178
# Epoch 20/20
# 625/625 [==============================] - 111s 177ms/step - loss: 0.0941 - acc: 0.9642 - val_loss: 0.2101 - val_acc: 0.9325
#
# Epoch 00020: val_loss did not improve from 0.19178

# %% [markdown]
# #### The best model after NUM_epech got an accuracy over the validation data of 95.75%.

# %%
def visualize_training(history, lw = 3):
    plt.figure(figsize=(10,10))
    plt.subplot(2,1,1)
    plt.plot(history.history['acc'], label = 'training', marker = '*', linewidth = lw)
    plt.plot(history.history['val_acc'], label = 'validation', marker = 'o', linewidth = lw)
    plt.title('Accuracy Comparison')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.grid(True)
    plt.legend(fontsize = 'x-large')

    plt.subplot(2,1,2)
    plt.plot(history.history['loss'], label = 'training', marker = '*', linewidth = lw)
    plt.plot(history.history['val_loss'], label = 'validation', marker = 'o', linewidth = lw)
    plt.title('Loss Comparison')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(fontsize = 'x-large')
    plt.grid(True)
    plt.show()


visualize_training(hist)

# %% [markdown]
# ### 4.3. Model Evaluation

# %%
#load the best model
model_.load_weights('weights.best.inc.male.hdf5')

# %%
# Test Data
x_test, y_test = generate_df(2, 'Male', TEST_SAMPLES)

# generate prediction
model_predictions = [np.argmax(model_.predict(feature)) for feature in x_test ]

# report test accuracy
test_accuracy = 100 * np.sum(np.array(model_predictions)==y_test) / len(model_predictions)
print('Model Evaluation')
print('Test accuracy: %.4f%%' % test_accuracy)
print('f1_score:', f1_score(y_test, model_predictions))
# Out:
# Model Evaluation
# Test accuracy: 92.6000%
# f1_score: 0.9209401709401709

# %% [markdown]
# The built model using transfer learning from the InceptionV3 and adding custom layers successfully recognize the gender giving certain picture with <b>92.6% of accuracy over the test data</b>.

# %% [markdown]
# ### 6. Let's play with the Model

# %%
#dictionary to name the prediction
gender_target = {0: 'Female'
                , 1: 'Male'}

def img_to_display(filename):
    # inspired on this kernel:
    # https://www.kaggle.com/stassl/displaying-inline-images-in-pandas-dataframe
    # credits to stassl :)
    
    i = Image.open(filename)
    i.thumbnail((200, 200), Image.LANCZOS)
    
    with BytesIO() as buffer:
        i.save(buffer, 'jpeg')
        return base64.b64encode(buffer.getvalue()).decode()
    

def display_result(filename, prediction, target):
    gender = 'Male'
    gender_icon = "https://png.pngtree.com/png-clipart/20190705/original/pngtree-man-avatar-icon-professional-man-character-png-image_4356027.jpg"
        
    if prediction[1] <= 0.5:
        gender_icon = "https://png.pngtree.com/png-clipart/20190614/original/pngtree-female-avatar-vector-icon-png-image_3725439.jpg"
        gender = 'Female'
            
    display_html = '''
    <div style="overflow: auto;  border: 2px solid #D8D8D8;
        padding: 5px; width: 480px;" >
        <img src="data:image/jpeg;base64,{}" style="float: left;" width="200" height="200">
        <div style="padding: 10px 0px 0px 20px; overflow: auto;">
            <img src="{}" style="float: left;" width="40" height="40">
            <h3 style="margin-left: 50px; margin-top: 2px;">Prediction: {}</h3>
            <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">{} probability</p>
            <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real gender: {}</p>
        </div>
    </div>
    '''.format(img_to_display(filename)
               , gender_icon
               , gender
               , "{0:.2f}%".format(round(max(prediction)*100,2))
               , gender_target[target]
               , filename.split('/')[-1]
               )

    display(HTML(display_html))

# %%
def gender_prediction(filename):
    '''
    predict the gender
    
    input: filename: str of the file name
        
    return: array of the prob of the targets.
    
    '''
    im = cv2.imread(filename)
    im = cv2.resize(cv2.cvtColor(im, cv2.COLOR_BGR2RGB), (178, 218)).astype(np.float32) / 255.0
    im = np.expand_dims(im, axis =0)
    
    # prediction
    result = model_.predict(im)
    prediction = np.argmax(result)
    
    return result

# %% [markdown]
# ### Prediction on 10 random test images

# %%
#select random images of the test partition
df_to_test = df_par_attr[(df_par_attr['partition'] == 2)].sample(10)

for index, target in df_to_test.iterrows():
    result = gender_prediction(images_folder + index)
    
    #display result
    display_result(images_folder + index, result[0], target['Male'])
# Out:
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 480px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://png.pngtree.com/png-clipart/20190705/original/pngtree-man-avatar-icon-professional-man-character-png-image_4356027.jpg" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Prediction: Male</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">99.97% probability</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real gender: Male</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 480px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://png.pngtree.com/png-clipart/20190705/original/pngtree-man-avatar-icon-professional-man-character-png-image_4356027.jpg" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Prediction: Male</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">89.06% probability</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real gender: Male</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 480px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://png.pngtree.com/png-clipart/20190614/original/pngtree-female-avatar-vector-icon-png-image_3725439.jpg" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Prediction: Female</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">99.99% probability</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real gender: Female</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 480px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://png.pngtree.com/png-clipart/20190614/original/pngtree-female-avatar-vector-icon-png-image_3725439.jpg" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Prediction: Female</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">99.92% probability</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real gender: Female</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 480px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://png.pngtree.com/png-clipart/20190614/original/pngtree-female-avatar-vector-icon-png-image_3725439.jpg" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Prediction: Female</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">99.99% probability</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real gender: Female</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 480px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://png.pngtree.com/png-clipart/20190705/original/pngtree-man-avatar-icon-professional-man-character-png-image_4356027.jpg" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Prediction: Male</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">99.26% probability</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real gender: Male</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 480px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://png.pngtree.com/png-clipart/20190705/original/pngtree-man-avatar-icon-professional-man-character-png-image_4356027.jpg" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Prediction: Male</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">99.61% probability</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real gender: Male</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 480px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://png.pngtree.com/png-clipart/20190614/original/pngtree-female-avatar-vector-icon-png-image_3725439.jpg" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Prediction: Female</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">100.00% probability</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real gender: Female</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 480px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://png.pngtree.com/png-clipart/20190705/original/pngtree-man-avatar-icon-professional-man-character-png-image_4356027.jpg" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Prediction: Male</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">96.31% probability</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real gender: Male</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 480px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://png.pngtree.com/png-clipart/20190614/original/pngtree-female-avatar-vector-icon-png-image_3725439.jpg" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Prediction: Female</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">100.00% probability</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real gender: Female</p>
#         </div>
#     </div>
